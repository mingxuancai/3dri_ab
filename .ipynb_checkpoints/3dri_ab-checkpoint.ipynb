# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
import numpy as np
import torch
import torch.nn as nn
import os
import signal
import cv2
import sys
import scipy.io as sio
import scipy
import imageio
import time
import skimage as sk
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider
from IPython.display import display, clear_output

from skimage.metrics import structural_similarity as ssim
from skimage.metrics import peak_signal_noise_ratio as psnr

# %%
from opticaltomography.forward_3dri import PhaseObject3D, TomographySolver
from opticaltomography.loss import mse_loss, sparsity_loss, total_variation_loss_2d, mse_loss_vec
import opticaltomography.opticsutils_3dri as utils
from opticaltomography.opticsutils_3dri import norm, norm_np, find_min_index, compute_psf_matrix_row

# %% [markdown]
# ### **(MUST LOAD)** Basic Setting

# %%
# Units in um
wavelength = 0.519  # emission wl excited by 488 nm
n_measure = 1.33    # n of water
n_b = 1.33          # background
mag = 20            # 20x mag
pixel_size = 6.5    # pixel size = 6.5 um * 6.5 um      
na = 0.45
dx = pixel_size / mag  # pixel size = 6.5 um -> pixel size at the sample plane: 6.5 / 20 um
dy = dx
dz = dx * 3

t_f32 = torch.float32
t_c64 = torch.complex64
np_f32 = np.float32
np_c64 = np.complex64

# %% [markdown]
# ### **(MUST LOAD)** Load illumination and phase obj

# %%
dir = "Dataset/"
mat_name = 'na_list_3D_rand_10.mat'
na_list = sio.loadmat(dir+mat_name)
fx_illu_list = na_list["na_list_3D_rand"][:, 0] * 3    # paraxial condition
fy_illu_list = na_list["na_list_3D_rand"][:, 1] * 3
fz_illu_list = na_list["na_list_3D_rand"][:, 2] * 0      # z layer at the z = 0 / 2D sample

# %%
# initial object, type: torch.float32
phantom = torch.zeros((200, 200, 25), dtype=t_f32)

# %%
# Set up ground truth object
phantom_coordinates = sio.loadmat("Dataset/phantomPoisson_nooverlap.mat")
phantom_temp = phantom_coordinates["phantomPoisson"]
phantom_obj = torch.ones_like(phantom) * 1.33 # set background
phantom_obj[50:150, 50:150, :] = phantom_obj[50:150, 50:150, :] + torch.from_numpy(phantom_temp) * 0.05 # ground truth
#solver_obj._x[50:150, 50:150, :] = torch.from_numpy(phantom_temp) * 0.1 # ground truth

# %%
"""
f, axes = plt.subplots(1, 1, figsize=(5, 3))
frames = []


def init():
    frames.append(axes.imshow(phantom[:,:,0]))
    axes.set_title('filled in phantom')

init()

def updateFrames(i):
    frames[0].set_data(phantom[:,:,i])

interact(updateFrames, i=IntSlider(min=0, max=24, step=1, value=0))
"""
# Out:
# "\nf, axes = plt.subplots(1, 1, figsize=(5, 3))\nframes = []\n\n\ndef init():\n    frames.append(axes.imshow(phantom[:,:,0]))\n    axes.set_title('filled in phantom')\n\ninit()\n\ndef updateFrames(i):\n    frames[0].set_data(phantom[:,:,i])\n\ninteract(updateFrames, i=IntSlider(min=0, max=24, step=1, value=0))\n"

# %% [markdown]
# ### Set up object solver (Different models)

# %%
solver_params = dict(wavelength = wavelength, na = na, \
                     RI_measure = n_measure, sigma = 2 * np.pi * dz / wavelength,\
                     fx_illu_list = fx_illu_list, fy_illu_list = fy_illu_list, fz_illu_list = fz_illu_list, \
                     voxel_size=(dy,dx,dz), pad = False, pad_size=(50,50))
phase_obj_3d = PhaseObject3D(shape=phantom.shape, voxel_size=(dy,dx,dz), RI_obj=phantom_obj, RI=n_b) # set phantom_obj as gt obj, n_b as background
solver_obj = TomographySolver(phase_obj_3d=phase_obj_3d, **solver_params)
solver_obj.setScatteringMethod(model="MultiPhaseContrast")  # select scattering model

# %%
"""
phantom_coordinates = sio.loadmat("Dataset/phantomPoisson_nooverlap.mat")
phantom_temp = phantom_coordinates["phantomPoisson"]
solver_obj._x[50:150, 50:150, :] = torch.from_numpy(phantom_temp) * 0.1 # ground truth
"""
# Out:
# '\nphantom_coordinates = sio.loadmat("Dataset/phantomPoisson_nooverlap.mat")\nphantom_temp = phantom_coordinates["phantomPoisson"]\nsolver_obj._x[50:150, 50:150, :] = torch.from_numpy(phantom_temp) * 0.1 # ground truth\n'

# %%
# Imshow ground truth object
f, axes = plt.subplots(1, 1, figsize=(5, 3))
frames = []


def init():
    frames.append(axes.imshow(solver_obj._x[:,:,0]))
    axes.set_title('Ground truth phase object')

init()

def updateFrames(i):
    frames[0].set_data(solver_obj._x[:,:,i])

interact(updateFrames, i=IntSlider(min=0, max=24, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=24), Output()), _dom_classes=('widget-interact',…
# <function __main__.updateFrames(i)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Forward Measurement

# %%
# from opticaltomography.forward_3dri import PhaseObject3D, TomographySolver
# ---------------------------#
# Generate forward prediction
# ---------------------------#
forward_field_mb, fields = solver_obj.forwardPredict(obj=solver_obj._x)

# %%
# ---------------------------#
# Show forward prediction
# ---------------------------#
# forward_field_mb[0].shape

# Show forward
f, axes = plt.subplots(1, 1, figsize=(5, 3))
frames = []

def init():
    # img = torch.fft.fftshift(torch.abs(solver_obj.test[0]))
    # frames.append(axes.imshow(torch.abs(solver_obj.test_spherical[0])))
    frames.append(axes.imshow(norm(forward_field_mb[0])))
    axes.set_title('Multi-slice')

init()

def updateFrames(i):
    # img = torch.fft.fftshift(torch.abs(solver_obj.test_spherical[i]))
    # frames.append(axes.imshow(img))
    frames[0].set_data(norm(forward_field_mb[i]))

interact(updateFrames, i=IntSlider(min=0, max=9, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=9), Output()), _dom_classes=('widget-interact',)…
# <function __main__.updateFrames(i)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Simulation of aberrated fluorescent USAF sample

# %% [markdown]
# ### **(MUST LOAD)** Load USAF target

# %%
usaf = np.array(plt.imread('Dataset/usaf_s.jpeg'))
usaf = sk.color.rgb2gray(cv2.resize(usaf, (50, 50)))
usaf = np.where(usaf > 0.8, 1, 0)
usaf = np.pad(usaf, ((75, 75), (75, 75)), mode='constant', constant_values=0)
plt.figure(figsize=(5, 3))
plt.imshow(usaf[50:150, 50:150])
plt.colorbar()
plt.title('GT USAF target')
# Out:
# Text(0.5, 1.0, 'GT USAF target')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Generate Forward measurement from the GT USAF target

# %%
# indices to fy_illu and fx_illu
indices = (np.argwhere(usaf == 1) - 100) / 200
fy_illu_usaf = indices[:,0]
fx_illu_usaf = indices[:,1]
fz_illu_usaf = np.zeros_like(fy_illu_usaf)

# %%
solver_params = dict(wavelength = wavelength, na = na, \
                     RI_measure = n_measure, sigma = 2 * np.pi * dz / wavelength,\
                     fx_illu_list = fx_illu_usaf, fy_illu_list = fy_illu_usaf, fz_illu_list = fz_illu_usaf, \
                     voxel_size=(dy,dx,dz), pad = False, pad_size=(50,50))
phase_obj_3d = PhaseObject3D(shape=phantom.shape, voxel_size=(dy,dx,dz), RI_obj=phantom_obj, RI=n_b) # set phantom_obj as gt obj, n_b as background
solver_obj = TomographySolver(phase_obj_3d=phase_obj_3d, **solver_params)
solver_obj.setScatteringMethod(model="MultiPhaseContrast")  # select scattering model

# %%
forward_field_mb, fields = solver_obj.forwardPredict(obj=solver_obj._x)

# %%
f, axes = plt.subplots(1, 1, figsize=(5, 3))
frames = []

def init():
    # img = torch.fft.fftshift(torch.abs(solver_obj.test[0]))
    # frames.append(axes.imshow(torch.abs(solver_obj.test_spherical[0])))
    frames.append(axes.imshow(forward_field_mb[0]))
    axes.set_title('Multi-slice')

init()

def updateFrames(i):
    # img = torch.fft.fftshift(torch.abs(solver_obj.test_spherical[i]))
    # frames.append(axes.imshow(img))
    frames[0].set_data(forward_field_mb[i])

interact(updateFrames, i=IntSlider(min=0, max=216, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=216), Output()), _dom_classes=('widget-interact'…
# <function __main__.updateFrames(i)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
images = []

for i in range(217):
    img = np.array(norm(forward_field_mb[i]))*255
    images.append(img.astype(np.uint8))

imageio.mimsave('Result/usaf50x50_raw_multi_slice.gif', images, duration=0.1)
"""
# Out:
# "\nimages = []\n\nfor i in range(217):\n    img = np.array(norm(forward_field_mb[i]))*255\n    images.append(img.astype(np.uint8))\n\nimageio.mimsave('Result/usaf50x50_raw_multi_slice.gif', images, duration=0.1)\n"

# %% [markdown]
# ## Generate forward measurement with spatially varying PSFs

# %%
forward_total = norm(torch.sum(forward_field_mb, axis=0))
plt.figure(figsize=(5,3))
plt.imshow(forward_total)
plt.title('Wide field measurement')
plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Pickup central PSF for deconvolution

# %%
# central_psf = forward_field_mb[120] # directly pick up the central one

solver_params = dict(wavelength = wavelength, na = na, \
                     RI_measure = n_measure, sigma = 2 * np.pi * dz / wavelength,\
                     fx_illu_list = [0], fy_illu_list = [0], fz_illu_list = [0], \
                     voxel_size=(dy,dx,dz), pad = False, pad_size=(50,50))
phase_obj_3d = PhaseObject3D(shape=phantom.shape, voxel_size=(dy,dx,dz), RI_obj=phantom_obj, RI=n_b) # set phantom_obj as gt obj, n_b as background
solver_obj = TomographySolver(phase_obj_3d=phase_obj_3d, **solver_params)
solver_obj.setScatteringMethod(model="MultiPhaseContrast")  # select scattering model

central_meas, _ = solver_obj.forwardPredict(obj=solver_obj._x)
central_psf = norm(central_meas[0])

plt.figure(figsize=(5,3))
plt.imshow(central_psf)
plt.title('Central PSF')
plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Restore Image using Richardson-Lucy algorithm with central PSF

# %%
deconvolved_RL = sk.restoration.richardson_lucy(np.array(forward_total), np.array(central_psf), num_iter = 300)

# %%
plt.figure(figsize=(5, 3))
plt.imshow(deconvolved_RL, vmin=0, vmax=1)
plt.title('Richardson-Lucy (iter=300)')
# plt.axis('off')
plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Generate forward measurement and deconvolve with spatially invariant PSF

# %%
forward_single = scipy.signal.convolve2d(usaf, central_psf, mode='same', boundary='symm')

forward_single = norm(torch.from_numpy(forward_single))

# %%
plt.figure(figsize=(5,3))
plt.imshow(forward_single)
plt.colorbar()
plt.title('Forward measurement with spatially-invariant PSF', fontsize=10, pad=10)
# Out:
# Text(0.5, 1.0, 'Forward measurement with spatially-invariant PSF')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
deconvolved_RL_single = sk.restoration.richardson_lucy(np.array(forward_single), np.array(central_psf), num_iter = 300)

# %%
plt.figure(figsize=(5, 3))
plt.imshow(deconvolved_RL_single)
plt.title('Spatially-invariant Richardson-Lucy (iter=300)', fontsize=10, pad=10)
# plt.axis('off')
plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Solve with spatially varying PSF

# %%
fy_varying = (np.arange(50, 150, 1) - 100) / 200
fx_varying = (np.arange(50, 150, 1) - 100) / 200

fy_varying, fx_varying = np.meshgrid(fy_varying, fx_varying)

fy_varying = fy_varying.reshape((-1,))
fx_varying = fx_varying.reshape((-1,))
fz_varying = np.zeros_like(fx_varying)

# %%
solver_params = dict(wavelength = wavelength, na = na, \
                     RI_measure = n_measure, sigma = 2 * np.pi * dz / wavelength,\
                     fx_illu_list = fx_varying, fy_illu_list = fy_varying, fz_illu_list = fz_varying, \
                     voxel_size=(dy,dx,dz), pad = False, pad_size=(50,50))
phase_obj_3d = PhaseObject3D(shape=phantom.shape, voxel_size=(dy,dx,dz), RI_obj=phantom_obj, RI=n_b)
solver_obj = TomographySolver(phase_obj_3d=phase_obj_3d, **solver_params)
solver_obj.setScatteringMethod(model="MultiPhaseContrast")

# %% [markdown]
# ### **(MUST LOAD)** Generate forward prediction of full PSFs in the 100x100 area

# %%
# predict_psf_meas, _ = solver_obj.forwardPredict(obj=solver_obj._x)

# %%
# np.save('predict_psf_usaf_100x100.npy', predict_psf_meas)

# %%
predict_psf_meas = np.load('Result/predict_psf_usaf_100x100.npy')

# %%
# predict_psf_meas.shape
# Out:
# (10000, 200, 200)

# %%
f, axes = plt.subplots(1, 1, figsize=(5, 3))
frames = []

def init():
    frames.append(axes.imshow(predict_psf_meas[0]))
    axes.set_title('Multi-slice')

init()

def updateFrames(i):
    frames[0].set_data(predict_psf_meas[i])

interact(updateFrames, i=IntSlider(min=0, max=1999, step=1, value=0))

# %%
"""
images = []

for i in range(1000):
    img = np.array(norm_np(predict_psf_meas[i]))*255
    images.append(img.astype(np.uint8))

imageio.mimsave('Result/predict_psf_meas.gif', images, duration=0.1)
"""

# %% [markdown]
# ## Case 1: Fill up full PSF transmission matrix

# %%
usaf_vec = usaf.reshape((-1,))

# %% [markdown]
# ### **(MUST LOAD)** PSF matrix

# %%
# compute PSF matrix
psf_matrix, psf_matrix_truncate, row_return = utils.PSF_matrix(predict_psf_meas, ymin=50, ymax=150, xmin=50, xmax=150, shape=(200,200))

# %%
# resize_psf_matrix = cv2.resize(psf_matrix,(4000,4000))

# %%
"""
plt.figure()
plt.imshow(psf_matrix, vmin=0, vmax=5e-5)
plt.colorbar()
plt.title('PSF Matrix')
plt.axis('off')
"""
# Out:
# "\nplt.figure()\nplt.imshow(psf_matrix, vmin=0, vmax=5e-5)\nplt.colorbar()\nplt.title('PSF Matrix')\nplt.axis('off')\n"

# %%
meas = norm_np(np.matmul(psf_matrix, usaf_vec).reshape((200,200)))

# %%
f, axes = plt.subplots(1, 3, figsize=(5,3))

axes[0].imshow(meas)
axes[0].axis('off')
axes[0].set_title('Matrix')
axes[1].imshow(forward_total)
axes[1].axis('off')
axes[1].set_title('Add')
axes[2].imshow(torch.from_numpy(meas)-forward_total)
axes[2].axis('off')
axes[2].set_title('Diff')

f.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       4 axes[0].axis('off')
#       5 axes[0].set_title('Matrix')
# ----> 6 axes[1].imshow(forward_total)
#       7 axes[1].axis('off')
#       8 axes[1].set_title('Add')
#
# NameError: name 'forward_total' is not defined
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Solve inverse problem with optimization

# %%
# Set GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
device_no = 1
torch.cuda.set_device(device_no)
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 3090'

# %%
# Initialize recon as the wide-field measurement
recon_obj_tensor = torch.tensor(np.zeros((200,200)).reshape((-1,)), requires_grad=True, device=device)
psf_matrix_tensor = torch.tensor(psf_matrix, device=device)
usaf_vec_tensor = torch.tensor(usaf_vec, device=device)
meas_tensor = torch.tensor(meas, device=device).reshape((-1,))

# %%
recon_obj_tensor = torch.tensor(np.zeros((200,200)).reshape((-1,)), requires_grad=True, device=device)

# %%
# Set parameters

n_iters = 2000
learning_rate = 10

optimizer = torch.optim.Adam([recon_obj_tensor], lr=learning_rate)
# optimizer = torch.optim.SGD([recon_obj_tensor], lr=learning_rate, momentum=0.9)

losslist = []

# %%
for epoch in range(n_iters):
    loss = 0
    optimizer.zero_grad()
    pred_forward = torch.matmul(psf_matrix_tensor, recon_obj_tensor)
    #pred_cpu = pred_forward.detach().to('cpu').reshape((200,200))
    loss = mse_loss_vec(pred_forward, meas_tensor) + total_variation_loss_2d(pred_forward, 1, device=device)
    
    losslist.append(loss)
    
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        with torch.no_grad():
            print(f'Reconstruction after iteration {epoch}, loss {loss:.4e}')
# Out:
# Reconstruction after iteration 0, loss 1.9289e-02
# Reconstruction after iteration 100, loss 3.4956e-02
# Reconstruction after iteration 200, loss 7.8424e-06
# Reconstruction after iteration 300, loss 4.9686e-06
# Reconstruction after iteration 400, loss 3.8582e-06
# Reconstruction after iteration 500, loss 3.3074e-06
# Reconstruction after iteration 600, loss 3.0037e-06
# Reconstruction after iteration 700, loss 2.8215e-06
# Reconstruction after iteration 800, loss 2.7042e-06
# Reconstruction after iteration 900, loss 2.6244e-06
# Reconstruction after iteration 1000, loss 2.5679e-06
# Reconstruction after iteration 1100, loss 2.5268e-06
# Reconstruction after iteration 1200, loss 2.4963e-06
# Reconstruction after iteration 1300, loss 2.4731e-06
# Reconstruction after iteration 1400, loss 2.4553e-06
# Reconstruction after iteration 1500, loss 2.4414e-06
# Reconstruction after iteration 1600, loss 2.4305e-06
# Reconstruction after iteration 1700, loss 2.4219e-06
# ...

# %%
recon_obj = recon_obj_tensor.detach().cpu().numpy()

# %%
plt.figure()
plt.imshow(recon_obj.reshape((200,200))[50:150,50:150])
plt.colorbar()
plt.title('Reconstruction with 100x100 matrix')

# Compute PSNR (Peak Signal-to-Noise Ratio)
psnr_value = psnr(recon_obj.reshape((200,200))[50:150,50:150], usaf[50:150, 50:150].astype(np.float64))

# Compute SSIM (Structural Similarity Index)
ssim_value = ssim(recon_obj.reshape((200,200))[50:150, 50:150], usaf[50:150, 50:150].astype(np.float64))

print(f'PSNR: {psnr_value:.2f} dB')
print(f'SSIM: {ssim_value:.2f}')
# Out:
# PSNR: 21.61 dB
# SSIM: 0.79
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Case 2: SVD full matrix

# %% [markdown]
# ### Sparse SVD

# %%
U, S, Vt = utils.SVD_sparse(psf_matrix, 130)

# %%
matrix_approximated = np.dot(U, np.dot(S, Vt))

# %%
matrix_approximated.shape
# Out:
# (40000, 40000)

# %%
plt.figure()
plt.imshow(cv2.resize(matrix_approximated,(4000,4000)),vmin=0,vmax=5e-5)
plt.axis('off')

# %%
plt.figure()
plt.imshow(cv2.resize(psf_matrix,(4000,4000)), vmin=0, vmax=5e-5)
plt.axis('off')

# %%
plt.figure()
plt.imshow(matrix_approximated[:,1500].reshape((200,200)))
plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.imshow(psf_matrix[:,1500].reshape((200,200)))
plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### PCA with facebook fast PCA algorithm
# #### https://amedee.me/post/pca-large-matrices/

# %%
import fbpca

# %%
# Compute PCA for the truncate psf matrix
(U, S, Va) = fbpca.pca(psf_matrix, k=200, raw=True, n_iter=2)

# %%
S
# Out:
# array([7.3485888 , 6.36617238, 6.3202577 , 5.70287876, 5.34314943,
#        5.31363513, 4.87784576, 4.86590385, 4.31606214, 4.28807182,
#        4.21910464, 3.98406557, 3.96779196, 3.47870851, 3.47291794,
#        3.33147254, 3.3121838 , 3.08431185, 3.07193847, 2.86874867,
#        2.73251782, 2.70237455, 2.47308877, 2.46451408, 2.30020642,
#        2.28612166, 2.26486258, 2.24953462, 2.02556856, 2.01404954,
#        1.78086333, 1.7662639 , 1.75383631, 1.70513678, 1.68590324,
#        1.64231285, 1.6383641 , 1.46957907, 1.45152374, 1.37476534,
#        1.35415836, 1.28722487, 1.28186406, 1.26741008, 1.24992261,
#        1.21342789, 1.1837657 , 1.15691437, 1.12356512, 1.10898295,
#        1.10605107, 1.09814784, 1.07723059, 1.07611498, 1.06706954,
#        1.05587301, 1.04689077, 1.03939635, 1.0314606 , 1.02531917,
#        1.02086687, 1.01563676, 1.01295707, 1.00781127, 1.00357319,
#        0.99468868, 0.98916188, 0.98675877, 0.98036028, 0.97449633,
# ...

# %%
plt.figure()
x = np.linspace(0, 200, 200)
plt.bar(x, height=S, color='skyblue')

plt.title('PCA of PSF matrix')
plt.ylabel('Variance')
plt.xlabel('Principal Components')
# Out:
# Text(0.5, 0, 'Principal Components')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
explained_variance_ratios = (S ** 2) / (S ** 2).sum()
plt.figure()
x = np.linspace(0, 200, 200)
plt.bar(x, height=explained_variance_ratios*100, color='skyblue')

plt.title('Explained variance ratios of PSF matrix')
plt.ylabel('Percentage (%)')
plt.xlabel('Principal Components')
# Out:
# Text(0.5, 0, 'Principal Components')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
explained_variance_ratios[:130].sum()
# Out:
# 0.9525528779113688

# %%
plt.figure()
plt.imshow(psf_matrix_truncate, vmin=0, vmax=5e-5)
plt.axis('off')
# Out:
# (-0.5, 9999.5, 39999.5, -0.5)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Compute SVD with dask array on truncate psf matrix
# #### https://blog.dask.org/2020/05/13/large-svds

# %%
import dask.array as da
import time

# %%
da_psf_matrix = da.from_array(psf_matrix, chunks=(4000, 4000))

# %%
u, s, v = da.linalg.svd_compressed(da_psf_matrix, k=1000, compute=False)

# %%
start_time = time.time()
u_np = u.compute()
s_np = s.compute()
v_np = v.compute()
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 6
#       4 v_np = v.compute()
#       5 end_time = time.time()
# ----> 6 print(f"Elapsed time: {elapsed_time} seconds")
#
# NameError: name 'elapsed_time' is not defined

# %%
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Elapsed time: 277.7030520439148 seconds

# %%
d = np.diag(s_np)

# %%
svd_psf_matrix = np.matmul(u_np, np.matmul(d, v_np))

# %%
np.save('Result/svd1000_u.npy', u_np)
np.save('Result/svd1000_diag_s.npy', d)
np.save('Result/svd1000_v.npy', v_np)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 np.save('Result/svd1000_u.npy', u_np)
#       2 np.save('Result/svd1000_diag_s.npy', d)
#       3 np.save('Result/svd1000_v.npy', v_np)
#
# NameError: name 'u_np' is not defined

# %%
plt.figure()
plt.imshow(cv2.resize(svd_psf_matrix,(4000,4000)), vmin=0, vmax=5e-5)
plt.title('PSF matrix after svd (k=1000)')
plt.axis('off')
# Out:
# (-0.5, 3999.5, 3999.5, -0.5)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.imshow(svd_psf_matrix[:,10850].reshape((200,200)), vmin=0)
plt.title('after svd (k=130)')
plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Compute PSNR (Peak Signal-to-Noise Ratio)
psnr_value = psnr(svd_psf_matrix[:,10850].reshape((200,200)), psf_matrix[:,10850].reshape((200,200)))

# Compute SSIM (Structural Similarity Index)
ssim_value = ssim(svd_psf_matrix[:,10850].reshape((200,200)), psf_matrix[:,10850].reshape((200,200)))

print(f'PSNR: {psnr_value:.2f} dB')
print(f'SSIM: {ssim_value:.2f}')
# Out:
# PSNR: 74.24 dB
# SSIM: 1.00

# %%
plt.figure()
plt.imshow(psf_matrix[:,10850].reshape((200,200)))
plt.title('gt img')
plt.colorbar()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# psf_matrix_full = utils.PSF_matrix_truncate2full(psf_matrix_truncate, row_return, 50, 150, 50, 150, (200,200))

# %% [markdown]
# ## Solve inverse problem with SVD PSF matrix

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
import numpy as np
import torch
import torch.nn as nn
import os
import signal
import cv2
import sys
import scipy.io as sio
import scipy
import imageio
import time
import skimage as sk
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider
from IPython.display import display, clear_output

from skimage.metrics import structural_similarity as ssim
from skimage.metrics import peak_signal_noise_ratio as psnr

from opticaltomography.forward_3dri import PhaseObject3D, TomographySolver
from opticaltomography.loss import mse_loss, sparsity_loss, total_variation_loss_2d, mse_loss_vec
import opticaltomography.opticsutils_3dri as utils
from opticaltomography.opticsutils_3dri import norm, norm_np, find_min_index, compute_psf_matrix_row

# %%
usaf = np.array(plt.imread('Dataset/usaf_s.jpeg'))
usaf = sk.color.rgb2gray(cv2.resize(usaf, (50, 50)))
usaf = np.where(usaf > 0.8, 1, 0)
usaf = np.pad(usaf, ((75, 75), (75, 75)), mode='constant', constant_values=0)
usaf_vec = usaf.reshape((-1,))

# %%
"""
predict_psf_meas = np.load('Result/predict_psf_usaf_100x100.npy')
usaf_vec = usaf.reshape((-1,))
psf_matrix, psf_matrix_truncate, row_return = utils.PSF_matrix(predict_psf_meas, ymin=50, ymax=150, xmin=50, xmax=150, shape=(200,200))
meas = norm_np(np.matmul(psf_matrix, usaf_vec).reshape((200,200)))
"""
# Out:
# "\npredict_psf_meas = np.load('Result/predict_psf_usaf_100x100.npy')\nusaf_vec = usaf.reshape((-1,))\npsf_matrix, psf_matrix_truncate, row_return = utils.PSF_matrix(predict_psf_meas, ymin=50, ymax=150, xmin=50, xmax=150, shape=(200,200))\nmeas = norm_np(np.matmul(psf_matrix, usaf_vec).reshape((200,200)))\n"

# %%
u_np = np.load('Result/svd1000_u.npy')
d = np.load('Result/svd1000_diag_s.npy')
v_np = np.load('Result/svd1000_v.npy')
psf_matrix = np.load('Result/psf_matrix.npy')
meas = np.load('Result/meas.npy')

# %%
# Set GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
device_no = 1
torch.cuda.set_device(device_no)
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 3090'

# %%
# Initialize recon as the wide-field measurement
recon_obj_tensor = torch.tensor(np.zeros((200,200)).reshape((-1,)), requires_grad=True, device=device)
u_np_tensor = torch.tensor(u_np, device=device)
d_tensor = torch.tensor(d, device=device)
v_np_tensor = torch.tensor(v_np, device=device)
meas_tensor = torch.tensor(meas, device=device).reshape((-1,))

# %%
# Set parameters

n_iters = 100
learning_rate = 0.01

optimizer = torch.optim.Adam([recon_obj_tensor], lr=learning_rate)
# optimizer = torch.optim.SGD([recon_obj_tensor], lr=learning_rate, momentum=0.9)

losslist = []

# %%
for epoch in range(n_iters):
    loss = 0
    optimizer.zero_grad()
    
    start_time = time.time()
    # psf_matrix_tensor = torch.matmul(u_np_tensor, torch.matmul(d_tensor, v_np_tensor))
    pred_forward = torch.matmul(torch.matmul(u_np_tensor, torch.matmul(d_tensor, v_np_tensor)), recon_obj_tensor)
    
    
    mse_loss = mse_loss_vec(pred_forward, meas_tensor) 

    # start_time = time.time()
    # tv_loss = total_variation_loss_2d(pred_forward, 1, device=device)
    # end_time = time.time()
    # elapsed_time = end_time - start_time
    # print(f"Elapsed time: {elapsed_time} seconds")
    
    loss = mse_loss
    
    losslist.append(loss)
    loss.backward()
    optimizer.step()
    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Elapsed time: {elapsed_time} seconds")
    # if epoch % 100 == 0:
    with torch.no_grad():
        print(f'Reconstruction after iteration {epoch}, loss {loss:.4e}')
# Out:
# Elapsed time: 0.02361154556274414 seconds
# Reconstruction after iteration 0, loss 1.9289e-02
# Elapsed time: 0.0006191730499267578 seconds
# Reconstruction after iteration 1, loss 1.4075e-02
# Elapsed time: 0.0007982254028320312 seconds
# Reconstruction after iteration 2, loss 1.0585e-02
# Elapsed time: 0.0007996559143066406 seconds
# Reconstruction after iteration 3, loss 7.9437e-03
# Elapsed time: 0.0006029605865478516 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 29
#      27 # if epoch % 100 == 0:
#      28 with torch.no_grad():
# ---> 29     print(f'Reconstruction after iteration {epoch}, loss {loss:.4e}')
#
# File ~/anaconda3/envs/FluoPhaseRecon/lib/python3.9/site-packages/torch/_tensor.py:659, in Tensor.__format__(self, format_spec)
#     657     return handle_torch_function(Tensor.__format__, (self,), self, format_spec)
# ...

# %%
recon_obj = recon_obj_tensor.detach().cpu().numpy()
plt.figure()
plt.imshow(recon_obj.reshape((200,200))[50:150,50:150])
plt.colorbar()
plt.title('Reconstruction with 100x100 matrix')
# Out:
# Text(0.5, 1.0, 'Reconstruction with 100x100 matrix')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
losslist_cpu = [tensor.detach().cpu() for tensor in losslist]
plt.figure()
plt.plot(losslist_cpu)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
losslist
# Out:
# [tensor(0.0193, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0141, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0106, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0079, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0059, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0044, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0033, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0026, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0022, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0020, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0018, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
#  tensor(0.0018, device='cuda:1', dtype=torch.float64, grad_fn=<AddBackward0>),
# ...
